# %%
import random

def choice():
    vvod = input('Выберите одну из категорий, набрав 1, 2 или 3 соответственно:\
    \n1) Растения \n2) Писатели и поэты \n3) Животные\n')
    if  vvod == '1':
        with open ('Растения.txt', 'r', encoding = 'utf-8') as f:
            list = f.readlines()
            i = random.choice(list)
    elif vvod == '2':
        with open ('Писатели и поэты.txt', 'r', encoding = 'utf-8') as g:
            list = g.readlines()
            i = random.choice(list)
    elif vvod == '3':
        with open ('Животные.txt', 'r', encoding = 'utf-8') as h:
            list = h.readlines()
            i = random.choice(list)
    else:
        print('Будьте внимательны, попробуйте снова.')
        game(choice())
    word = []
    for l in i.strip().lower():
        word.append(l)
    # word - это загаданное слово по буквам 
    return word

# %%
def game(word):
    n = len(word)
    slovo = []
    p = 6
    for number in range(n):
        slovo.append('_')
    # slovo - это список из "_", количество которых равно колличеству букв в слове
    whole = ''.join(word)
    # whole - это строка = загаданное слово
    print('У вас есть ', p, ' попыток, чтобы угадать слово из ', n, ' букв:\n', ' '.join(slovo), sep='')
    alph = 'абвгдеёжзийклмнопрстуфхцчшщьыъэюя'
    x = 1
    tries = []
    while x <= 6:
        if '_' not in slovo:
            print('Вы победили!\n')
            if input('Хотите начать заново? Нажмите Enter.') == '':
                game(choice())
        letter = input('\nВведите букву: ')
        if letter.lower() in tries:
            print('Вы уже вводили эту букву. Попробуйте другую.')
        elif letter in alph:
            tries.append(letter)
            if letter in word:
                for number in range(len(whole)):
                    if word[int(number)] == letter:
                        slovo.pop(int(number))
                        slovo.insert(int(number), letter)
                print('Буква есть в слове:', ' '.join(slovo))
                continue
            else:
                x += 1
                p -= 1
                if p == 5:
                    print('Такой буквы нет в слове. У вас осталось 5 попыток.')
                    print(' __\n|  |\n|  0\n|\n|')
                elif p == 4:
                    print('Такой буквы нет в слове. У вас осталось 4 попытки.')
                    print(' __\n|  |\n| \\0\n|\n|')
                elif p == 3:
                    print('Такой буквы нет в слове. У вас осталось 3 попытки.')
                    print(' __\n|  |\n| \\0/\n|\n|')
                elif p == 2:
                    print('Такой буквы нет в слове. У вас осталось 2 попытки.')
                    print(' __\n|  |\n| \\0/\n|  |\n|')
                elif p == 1:
                    print('Такой буквы нет в слове. У вас осталось 1 попытка.')
                    print(' __\n|  |\n| \\0/\n|  |\n| /')
                elif p == 0:
                    print('Такой буквы нет в слове. У вас осталось 0 попыток.')
                    print(' __\n|  |\n| \\0/\n|  |\n| / \\')
                continue
        else:
            print('Это не буква, будьте внимательнее.')
            continue
    else:
        print('Попытки закончились. Вы проиграли.\n')
        if input('Хотите начать заново? Нажмите Enter.') == '':
            game(choice())

# %%
def main():
    game(choice())
    
if __name__=='__main__':
    main()
# Out:
# Выберите одну из категорий, набрав 1, 2 или 3 соответственно:
# 1) Растения
# 2) Писатели и поэты
# 3) Животные
# 1
# У вас есть 6 попыток, чтобы угадать слово из 7 букв:
# _ _ _ _ _ _ _
#
# Введите букву: p
# Это не буква, будьте внимательнее.
#
# Введите букву: с
# Такой буквы нет в слове. У вас осталось 5 попыток.
#  __
# |  |
# |  0
# |
# |
#
# Введите букву: у
# Такой буквы нет в слове. У вас осталось 4 попытки.
#  __
# |  |
# | \0
# |
# |
#
# Введите букву: и
# Такой буквы нет в слове. У вас осталось 3 попытки.
#  __
# |  |
# | \0/
# |
# |
#
# Введите букву: х
# Такой буквы нет в слове. У вас осталось 2 попытки.
#  __
# |  |
# | \0/
# |  |
# |
#
# Введите букву: ъ
# Такой буквы нет в слове. У вас осталось 1 попытка.
#  __
# |  |
# | \0/
# |  |
# | /
#
# Введите букву: ю
# Буква есть в слове: _ ю _ _ _ _ _
#
# Введите букву: э
# Такой буквы нет в слове. У вас осталось 0 попыток.
#  __
# |  |
# | \0/
# |  |
# | / \
# Попытки закончились. Вы проиграли.
#
# Хотите начать заново? Нажмите Enter.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-42944d7efcc5> in <module>()
#       3
#       4 if __name__=='__main__':
# ----> 5     main()
#
# <ipython-input-3-42944d7efcc5> in main()
#       1 def main():
# ----> 2     game(choice())
#       3
#       4 if __name__=='__main__':
#       5     main()
#
# <ipython-input-2-465d707ccbdb> in game(word)
#      59             game(choice())
#      60         else:
# ---> 61             end
#
# NameError: name 'end' is not defined
